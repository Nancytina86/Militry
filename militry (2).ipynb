# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import tensorflow as tf

if tf.test.gpu_device_name():
    print("Gpu found")
    # !nvidia-smi
else:
    print("Not found")
# Out:
# Gpu found
# Thu Jul 24 14:02:47 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   63C    P0             31W /   70W |     103MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.6 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 53.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 23.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.8 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !unzip -q /kaggle/input/military/military_object_dataset.zip -d /kaggle/working/
# Out:
# unzip:  cannot find or open /kaggle/input/military/military_object_dataset.zip, /kaggle/input/military/military_object_dataset.zip.zip or /kaggle/input/military/military_object_dataset.zip.ZIP.

# %%
import os

# List what's inside your Kaggle input directory
os.listdir("/kaggle/input")
# Out:
# ['military']

# %%
os.listdir("/kaggle/input/military")
# Out:
# ['military_object_dataset']

# %%
# !pip install ultralytics --upgrade -q

# %%
import os

# Should show ['train', 'val', 'test', 'military_dataset.yaml']
print(os.listdir("/kaggle/input/military/military_object_dataset"))
# Out:
# ['dataset.md', 'val', 'military_dataset.yaml', 'test', 'train']

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/kaggle/working/military_object_dataset/military_dataset.yaml",
    epochs=20,
    imgsz=640,
    batch=16,
    save_period=1,
    project="/kaggle/working",
    name="military_yolo"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 75.2MB/s]
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import os

os.listdir("/kaggle/working")
# Out:
# ['military_yolo', 'yolov8n.pt', '.virtual_documents']

# %%
import zipfile

zip_path = "/kaggle/input/military/military_object_dataset.zip"
extract_path = "/kaggle/working"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_36/688074454.py in <cell line: 0>()
#       4 extract_path = "/kaggle/working"
#       5
# ----> 6 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#       7     zip_ref.extractall(extract_path)
#
# /usr/lib/python3.11/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1293             while True:
#    1294                 try:
# -> 1295                     self.fp = io.open(file, filemode)
#    1296                 except OSError:
#    1297                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/military/military_object_dataset.zip'

# %%
import os

os.listdir("/kaggle/input")
# Out:
# ['military']

# %%
os.listdir("/kaggle/input/military")
# Out:
# ['military_object_dataset']

# %%
from ultralytics import YOLO

# Load YOLOv8 model (smallest)
model = YOLO("yolov8n.pt")

# Start training
model.train(
    data="/kaggle/input/military_object_dataset/military_dataset.yaml",  # ✅ Correct path
    epochs=20,
    imgsz=640,
    batch=16,
    save_period=1,
    project="/kaggle/working",
    name="military_yolo"
)
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load YOLOv8n (smallest model, change to yolov8s.pt/m.pt/l.pt if needed)
model = YOLO("yolov8n.pt")

# Train the model
model.train(
    data="/kaggle/input/military/military_object_dataset/military_dataset.yaml",
    epochs=20,
    imgsz=640,
    batch=16,
    save_period=1,  # Save model at every epoch
    project="/kaggle/working",  # Output directory
    name="military_yolo"        # Subfolder name
)
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls /kaggle/input/military/military_object_dataset
# Out:
# dataset.md  military_dataset.yaml  test  train	val

# %%
# !ls /kaggle/input/military/military_object_dataset/train/images | head
# !ls /kaggle/input/military/military_object_dataset/val/images | head
# Out:
# 000065.jpg
# 000066.jpg
# 000067.jpg
# 000068.jpg
# 000069.jpg
# 000070.jpg
# 000071.jpg
# 000072.jpg
# 000073.jpg
# 000074.jpg
# ls: write error: Broken pipe
# 002684.jpg
# 002685.jpg
# 002686.jpg
# 002687.jpg
# 002688.jpg
# 002689.jpg
# 002690.jpg
# 002691.jpg
# 002692.jpg
# 002693.jpg
# ls: write error: Broken pipe

# %%
from ultralytics import YOLO

# Load a small YOLOv8 model (you can change to yolov8s.pt or yolov8m.pt if needed)
model = YOLO("yolov8n.pt")

# Start training
model.train(
    data="/kaggle/input/military/military_object_dataset/military_dataset.yaml",  # ✅ Your .yaml path
    epochs=20,
    imgsz=640,
    batch=16,
    save_period=1,
    project="/kaggle/working",  # 👈 Outputs will go here
    name="military_yolo"
)
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a small YOLOv8 model (you can change to yolov8s.pt or yolov8m.pt if needed)
model = YOLO("yolov8m.pt")

# Start training
model.train(
    data="/kaggle/working/fixed_military_dataset.yaml",  # ✅ Your .yaml path
    epochs=50,
    imgsz=640,
    batch=16,
    save_period=1,
    project="/kaggle/working",  # 👈 Outputs will go here
    name="military_yolo"
)
# Out:
# Ultralytics 8.3.184 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.8 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.3 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.2 MB/s eta 0:00:00:00:0100:01
# ...

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO("/kaggle/input/86mili/best (4).pt")

# Validate on your dataset
metrics = model.val(data="/kaggle/working/fixed_military_dataset.yaml")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.183 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,846,708 parameters, 0 gradients, 78.7 GFLOPs
# ...
# val: Fast image access ✅ (ping: 15.9±18.4 ms, read: 6.2±6.6 MB/s, size: 94.1 KB)
# val: Scanning /kaggle/input/military/military_object_dataset/val/labels... 2941 images, 273 backgrounds, 0 corrupt: 100%|██████████| 2941/2941 [00:53<00:00, 55.12it/s]
# WARNING ⚠️ val: Cache directory /kaggle/input/military/military_object_dataset/val is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 184/184 [00:33<00:00,  5.42it/s]
# ...

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO("/kaggle/input/bestbest/best (11).pt")

# Validate on your dataset
metrics = model.val(data="/kaggle/working/fixed_military_dataset.yaml")
# Out:
# Ultralytics 8.3.189 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,846,708 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 152.1±82.6 MB/s, size: 93.9 KB)
# val: Scanning /kaggle/input/military/military_object_dataset/val/labels... 2941 images, 273 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2941/2941 864.8it/s 3.4s
# WARNING ⚠️ val: Cache directory /kaggle/input/military/military_object_dataset/val is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 184/184 2.8it/s 1:05s
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# ...

# %%
from ultralytics import YOLO

# load previous weights but NOT resume
model = YOLO("/kaggle/input/l8mili/last (10).pt")

# start new training run (fine-tuning)
results = model.train(
    data="/kaggle/working/fixed_military_dataset.yaml",
    epochs=70,          # how many MORE epochs you want
    save_period=1,      # save every epoch
    project="runs/train",
    name="exp_yolov8l_finetune"
)
# Out:
# Ultralytics 8.3.183 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
yaml_content = """
train: /kaggle/input/military/military_object_dataset/train/images
val: /kaggle/input/military/military_object_dataset/val/images
test: /kaggle/input/military/military_object_dataset/test/images

nc: 12
names: [ "class1", "class2", "class3", "class4", "class5", "class6", "class7", "class8", "class9", "class10", "class11", "class12" ]
"""

with open("/kaggle/working/fixed_military_dataset.yaml", "w") as f:
    f.write(yaml_content)

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/input/86mili/best (4).pt")

model.train(
    data="/kaggle/working/fixed_military_dataset.yaml",  # ✅ updated path
    epochs=70,
    imgsz=640,
    batch=16,
    save_period=1,
    project="/kaggle/working",
    name="military_yolo"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.184 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cat /kaggle/working/fixed_military_dataset.yaml
# Out:
# train: /kaggle/input/military/military_object_dataset/train/images
# val: /kaggle/input/military/military_object_dataset/val/images
# test: /kaggle/input/military/military_object_dataset/test/images
#
# nc: 12
# names: [ "class1", "class2", "class3", "class4", "class5", "class6", "class7", "class8", "class9", "class10", "class11", "class12" ]

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/kaggle/working/fixed_military_dataset.yaml",  # ✅ updated path
    epochs=20,
    imgsz=640,
    batch=16,
    save_period=1,
    project="/kaggle/working",
    name="military_yolo"
)
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load the model from your saved weights
model = YOLO("/kaggle/input/military-6/kaggle/working/military_yolo6/weights/last.pt")

# %%
yaml_content = """
train: /kaggle/input/military/military_object_dataset/train/images
val: /kaggle/input/military/military_object_dataset/val/images
test: /kaggle/input/military/military_object_dataset/test/images

nc: 12
names: [ "class1", "class2", "class3", "class4", "class5", "class6", "class7", "class8", "class9", "class10", "class11", "class12" ]
"""

with open("/kaggle/working/fixed_military_dataset.yaml", "w") as f:
    f.write(yaml_content)
print("YAML file recreated.")
# Out:
# YAML file recreated.

# %%
import os
print(os.path.exists("/kaggle/working/fixed_military_dataset.yaml"))
# Out:
# True

# %%
model.train(
    data="/kaggle/working/fixed_military_dataset.yaml",
    epochs=50,  # This will continue up to epoch 50
    imgsz=640,
    batch=16,
    project="/kaggle/working",
    name="military_yolo6_v2",
    model="/kaggle/input/military-6/kaggle/working/military_yolo6/weights/last.pt"  # load last model manually
)
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import FileLink

# Path to your trained model
model_path = "/kaggle/working/military_yolo6_v2"
# Create a clickable link to download
FileLink(model_path)

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00:00:0100:01
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")  # or any other pretrained model like "yolov8m.pt"

model.train(
    data="/kaggle/working/fixed_military_dataset.yaml",  # your dataset config
    epochs=10,
    imgsz=640,
    batch=16,
    project="/kaggle/working",
    name="military_yolo8m_exp",  # this folder will be created
    save=True,           # saves last.pt and best.pt
    save_period=1        # saves weights every epoch
)
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load your uploaded last.pt checkpoint
model = YOLO("/kaggle/input/newmil/last (2).pt")  # Replace with actual path if needed

# Continue training for 30 more epochs
model.train(
    data="/kaggle/working/fixed_military_dataset.yaml",  # Your dataset config
    epochs=40,
    imgsz=416,             # Keep it consistent
    batch=16,              # Adjust if you face memory issues
    workers=2,
    save=True,
    save_period=1,
    project="military_yolo8m_final",
    name="exp_final_continue2",  # New folder for logs and weights
    resume=False                 # Start fresh using last.pt weights
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/input/newmilnew/epoch39.pt")

model.train(
    data="/kaggle/working/fixed_military_dataset.yaml",
    epochs=25,  # This means 30 MORE epochs, continuing from epoch 39 → will reach 69 total
    imgsz=416,
    batch=16,
    workers=2,
    save=True,
    save_period=1,
    project="military_yolo8m_final",
    name="exp_final_continue4",
      # important: resume must be True
)
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")  # or your last.pt to resume

model.train(
    data="/kaggle/working/fixed_military_dataset.yaml",
    epochs=30,
    imgsz=416,               # Best accuracy
    batch=8,                 # Safer for Kaggle
    workers=1,               # More stable
    save=True,
    save_period=1,
    project="/kaggle/working/military_yolo8m_final",
    name="exp_final",
    amp=True,
    
)
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import shutil

# Zip the folder
shutil.make_archive('military_yolo6_v2', 'zip', '/kaggle/working/military_yolo6_v2')
# Out:
# '/kaggle/working/military_yolo6_v2.zip'

# %%
from IPython.display import FileLink

# Create download link for the zip file
FileLink('military_yolo6_v2.zip')
# Out:
# /kaggle/working/military_yolo6_v2.zip

# %%
from ultralytics import YOLO

model_best = YOLO("/kaggle/working/military_yolo6_v2/weights/best.pt")
metrics_best = model_best.val(data="/kaggle/working/fixed_military_dataset.yaml")
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 246.5±360.2 MB/s, size: 487.3 KB)
# val: Scanning /kaggle/input/military/military_object_dataset/val/labels... 2941 images, 273 backgrounds, 0 corrupt: 100%|██████████| 2941/2941 [00:06<00:00, 426.15it/s]
# WARNING ⚠️ val: Cache directory /kaggle/input/military/military_object_dataset/val is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 184/184 [00:24<00:00,  7.55it/s]
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# ...

# %%
from ultralytics import YOLO

# Load full checkpoint
model = YOLO("/kaggle/input/49mili/epoch49 (2).pt")

# Resume and force 150 total epochs
results = model.train(
    data="/kaggle/working/fixed_military_dataset.yaml",
    project="runs/train",
    name="exp_yolov8m_contd",
    epochs=60,       # will override checkpoint's 50
    save_period=1
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.186 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import torch
from ultralytics import YOLO
from ultralytics.nn.tasks import DetectionModel

# Path to your checkpoint
CHECKPOINT = "/kaggle/input/53mili/epoch53.pt"

# 1) Allowlist DetectionModel so torch can unpickle YOLO checkpoint
torch.serialization.add_safe_globals([DetectionModel])

# 2) Load checkpoint with weights_only=False
ckpt = torch.load(CHECKPOINT, map_location="cpu", weights_only=False)

# 3) Fix epochs inside args (YOLO uses this for resuming training)
if "train_args" in ckpt:
    ckpt["train_args"]["epochs"] = 100  # set new target
if "epochs" in ckpt.get("args", {}):
    ckpt["args"]["epochs"] = 100

# 4) Save back as patched checkpoint
torch.save(ckpt, "patched_epoch53.pt")

# 5) Load with Ultralytics YOLO and resume training
model = YOLO("patched_epoch53.pt")
model.train(data="coco128.yaml", epochs=100, resume=True, save=True,save_period=1)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.189 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import torch
from ultralytics import YOLO
from ultralytics.nn.tasks import DetectionModel

# Path to your checkpoint
CHECKPOINT = "/kaggle/input/85milii/epoch99.pt"

# 1) Allowlist DetectionModel so torch can unpickle YOLO checkpoint
torch.serialization.add_safe_globals([DetectionModel])

# 2) Load checkpoint
ckpt = torch.load(CHECKPOINT, map_location="cpu", weights_only=False)

# 3) Patch epochs correctly (handle both cases: train_args and args)
extra_epochs = 55

if "train_args" in ckpt:
    ckpt["train_args"]["epochs"] = ckpt["train_args"].get("epochs", 99) + extra_epochs

if "args" in ckpt:
    ckpt["args"]["epochs"] = ckpt["args"].get("epochs", 99) + extra_epochs

# 4) Save patched checkpoint
torch.save(ckpt, "patched_epoch99.pt")

# 5) Load with Ultralytics YOLO and resume training
model = YOLO("patched_epoch99.pt")

# Safely get the new epoch count (prefer train_args > args > fallback)
new_epochs = (
    ckpt.get("train_args", {}).get("epochs")
    or ckpt.get("args", {}).get("epochs")
    or (99 + extra_epochs)
)

model.train(
    data="coco128.yaml",   # <-- replace with your dataset.yaml
    epochs=new_epochs,
    resume=True,
    save=True,
    save_period=1,
    augment=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.189 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import torch
from ultralytics import YOLO
from ultralytics.nn.tasks import DetectionModel

# Path to your checkpoint
CHECKPOINT = "/kaggle/input/85milii/epoch99.pt"

# 1) Allowlist DetectionModel so torch can unpickle YOLO checkpoint
torch.serialization.add_safe_globals([DetectionModel])

# 2) Load checkpoint
ckpt = torch.load(CHECKPOINT, map_location="cpu", weights_only=False)

# 3) Patch epochs correctly
extra_epochs = 50
if "train_args" in ckpt:
    ckpt["train_args"]["epochs"] = ckpt["train_args"].get("epochs", 99) + extra_epochs
if "args" in ckpt:
    ckpt["args"]["epochs"] = ckpt["args"].get("epochs", 99) + extra_epochs

# 4) Save patched checkpoint
torch.save(ckpt, "patched_epoch99.pt")

# 5) Load with Ultralytics YOLO
model = YOLO("patched_epoch99.pt")

# Get new epoch target safely
new_epochs = (
    ckpt.get("train_args", {}).get("epochs")
    or ckpt.get("args", {}).get("epochs")
    or (99 + extra_epochs)
)

# ✅ Correct training call (no 'hyp' bug)
model.train(
    data="coco128.yaml",     # <-- replace with your dataset.yaml
    epochs=new_epochs,       # continue for 50 more
    resume=True,
    save=True,
    save_period=1,
    augment=True,            # enable built-in augmentations
    lr0=0.001,               # tweak learning rate if needed
    imgsz=640,               # training image size
    degrees=10,              # random rotation
    translate=0.1,           # translation
    scale=0.5,               # random scaling
    shear=2,                 # shear
    flipud=0.5,              # vertical flip
    fliplr=0.5,              # horizontal flip
    mosaic=1.0,              # enable mosaic augmentation
    mixup=0.2                # enable mixup augmentation
)
# Out:
# Ultralytics 8.3.189 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
